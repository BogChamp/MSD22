# %%
import os
import numpy as np
from torch.utils.data import TensorDataset, DataLoader, Dataset
import torch.nn.functional as F
import torch

from math import floor
import pandas as pd
import scipy.io as sio
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix,f1_score

import torch.nn as nn
from typing import List, Optional, Tuple, Union
import torch.distributed as dist
import torchvision.transforms as T
import pytorch_lightning as pl

# %%
def load_hasc_ds(path, window, mode='train'):

    X, lbl = extract_windows_hasc(path, window, 5)

    if mode == "all":
        return X, lbl

    train_size = floor(0.8 * X.shape[0])
    print(train_size)
    if mode =="train":
        trainx = X[0:train_size]
        trainlbl =lbl[0:train_size]
        idx = np.arange(trainx.shape[0])
        np.random.shuffle(idx)
        trainx = trainx[idx,]
        trainlbl = trainlbl[idx]
        print('train samples : ', train_size)
        return trainx, trainlbl

    else:
        testx = X[train_size:]
        testlbl = lbl[train_size:]
        print('test shape {} and number of change points {} '.format(testx.shape, len(np.where(testlbl>0)[0])))

        return testx, testlbl



def extract_windows_hasc(path, window_size, step):

    dataset = sio.loadmat(path+"hasc.mat")
    window_size
    windows = []
    lbl = []
    first = True
    num_cp = 0
    x = np.array(dataset['Y'])
    cp = np.array(dataset['L'])

    ts = np.sqrt(np.power(x[:, 0], 2) + np.power(x[:, 1], 2) + np.power(x[:, 2], 2))
    for i in range(0, ts.shape[0] - window_size, windows_size // 5):
        windows.append(np.array(ts[i:i + window_size]))
        is_cp = np.where(cp[i:i + window_size] == 1)[0]
        if is_cp.size == 0:
            is_cp = [0]
        else:
            num_cp += 1
        lbl.append(is_cp[0])

    print("number of samples : {} /  number of samples with change point : {}".format(len(windows), num_cp))
    windows = np.array(windows)

    return windows, np.array(lbl)

def load_usc_ds(path, window, mode='train'):
    X, lbl = extract_windows_usc(path, window, mode)

    if mode == "all":
        return X, lbl
    train_size = int(floor(0.8 * X.shape[0]))
    if mode == "train":
        trainx = X[0:train_size]
        trainlbl = lbl[0:train_size]
        idx = np.arange(trainx.shape[0])
        np.random.shuffle(idx)
        trainx = trainx[idx,]
        trainlbl = trainlbl[idx]
        print('train samples : ', train_size)
        return trainx, trainlbl

    else:
        testx = X[train_size:]
        testlbl = lbl[train_size:]
        print('test shape {} and number of change points {} '.format(testx.shape, len(np.where(testlbl > 0)[0])))

        return testx, testlbl


def extract_windows_usc(path, window_size, mode="train"):
    windows = []
    lbl = []
    dataset = sio.loadmat(path+"usc.mat")

    ts = np.array(dataset['Y'])
    ts = ts[:,0]
    cp = np.array(dataset['L'])
    cp = cp[:,0]

    num_cp = 0

    for i in range(0, ts.shape[0] - window_size, window_size // 5):
        windows.append(np.array(ts[i:i + window_size]))
        is_cp = np.where(cp[i:i + window_size] == 1)[0]
        if is_cp.size == 0:
            is_cp = [0]
        else:
            num_cp += 1
        lbl.append(is_cp[0])

    print("number of samples : {} /  number of samples with change point : {}".format(len(windows), num_cp))
    windows = np.array(windows)

    return windows, np.array(lbl)

def load_dataset(path, ds_name, win, bs, mode="train"):
    if ds_name == 'HASC':
        trainx, trainlbl = load_hasc_ds(path, window = win, mode=mode)
    elif ds_name == "USC":
        trainx, trainlbl = load_usc_ds(path, window= win, mode=mode)
    else:
        raise ValueError("Undefined Dataset.")

    trainlbl = trainlbl.reshape((trainlbl.shape[0], 1))
    print(trainx.shape, trainlbl.shape)
    dataset = np.concatenate((trainlbl, trainx), 1)

    print("dataset shape : ", dataset.shape)
    if mode == "test":
        return dataset

    train_ds = TensorDataset(torch.from_numpy(dataset))
    return train_ds

def load_future(path, ds_name, win, bs, mode="train"):
    if ds_name == 'HASC':
        trainx, trainlbl = load_hasc_ds(path, window = 2 * win, mode=mode)
    elif ds_name == "USC":
        trainx, trainlbl = load_usc_ds(path, window=2 * win, mode=mode)
    else:
        raise ValueError("Undefined Dataset.")

    trainlbl = trainlbl.reshape((trainlbl.shape[0], 1))
    print(trainx.shape, trainlbl.shape)
    dataset = np.concatenate((trainlbl, trainx), 1)

    print("dataset shape : ", dataset.shape)
    if mode == "test":
        return dataset

    train_ds = TensorDataset(torch.from_numpy(dataset))
    return train_ds

# %%
def estimate_CPs(sim, gt, name, train_name, metric='cosine', threshold=0.5):

    est_cp = np.zeros(sim.shape[0])
    est_cp[np.where(sim < threshold)[0]] = 1
    tn, fp, fn, tp = confusion_matrix(gt, est_cp).ravel()
    f1 = f1_score(gt, est_cp)

    gt_id = np.where(gt == 1)[0]
    print("tn {}, fp {}, fn {}, tp {} ----- f1-score {}".format(tn, fp, fn, tp, f1))

    i = 1
    pos, seq_tp, seq_fn, seq_fp = 0, 0, 0, 0

    while i < gt.shape[0]:
        if gt[i] == 1:
            pos += 1
            j = i
            while gt[i] == 1:
                i += 1

            if np.sum(est_cp[j:i]) > 0:
                seq_tp += 1
                est_cp[j:i] = 0
            else:
                seq_fn += 1

        i += 1

    seq_fp = np.where(np.diff(est_cp) == 1)[0].shape[0]
    seq_f1 = (2 * seq_tp) / (2 * seq_tp + seq_fn + seq_fp)

    print("SEQ : Pos {}, fp {}, fn {}, tp {} ----- f1-score {}".format(pos, seq_fp, seq_fn, seq_tp, seq_f1))
    result = "tn, {}, fp, {}, fn, {}, tp, {}, f1-score, {}, Pos, {}, seqfp, {}, seqfn, {}, seqtp, {}, seqf1, {}\n".format(tn, fp, fn, tp, f1, pos, seq_fp, seq_fn, seq_tp, seq_f1)
    return result

# %%
DS_NAME = 'USC'
DATA_PATH = './data/'
OUTPUT_PATH = os.path.join('./output/', DS_NAME)
MODEL_PATH = os.path.join('./output/', "model")
LOSS = 'nce'
SIM = 'cosine'
GPU = 0

WIN = 100
CODE_SIZE = 10
BATCH_SIZE = 32
EPOCHS = 40
LR = 1e-4
TEMP = 0.5
TAU = 0.1
BETA = 1
EVALFREQ = 25
decay_steps = 1000


train_name = "CP2_model_" + DS_NAME + "_T" + str(TEMP) + "_WIN" + str(WIN) + \
             "_BS" + str(BATCH_SIZE) + "_CS" + str(CODE_SIZE) + "_lr" + str(LR) + \
             "_LOSS" + LOSS +  "_SIM" + SIM + "_TAU" + str(TAU) + "_BETA" + str(BETA)
print("------------------------------------>>> " + train_name)

train_ds = load_dataset(DATA_PATH, DS_NAME, WIN, BATCH_SIZE, mode = "train")
test_ds = load_dataset(DATA_PATH, DS_NAME, WIN, BATCH_SIZE, mode = "test")
# Out:
# ------------------------------------>>> CP2_model_USC_T0.5_WIN100_BS32_CS10_lr0.0001_LOSSnce_SIMcosine_TAU0.1_BETA1
# number of samples : 4677 /  number of samples with change point : 175
# train samples :  3741
# (3741, 100) (3741, 1)
# dataset shape :  (3741, 101)
# number of samples : 4677 /  number of samples with change point : 175
# test shape (936, 100) and number of change points 35
# (936, 100) (936, 1)
# dataset shape :  (936, 101)

# %%
class ProjectionHead(nn.Module):
    def __init__(
        self, 
        blocks: List[Tuple[int, int, Optional[nn.Module], Optional[nn.Module]]]
    ):
        super(ProjectionHead, self).__init__()

        layers = []
        for input_dim, output_dim, batch_norm, non_linearity in blocks:
            use_bias = not bool(batch_norm)
            layers.append(nn.Linear(input_dim, output_dim, bias=use_bias))
            if batch_norm:
                layers.append(batch_norm)
            if non_linearity:
                layers.append(non_linearity)
        self.layers = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor):
        return self.layers(x)
        
class BarlowTwinsProjectionHead(ProjectionHead):
    def __init__(self,
                 input_dim: int = 2048,
                 hidden_dim: int = 8192,
                 output_dim: int = 8192):
        super(BarlowTwinsProjectionHead, self).__init__([
            (input_dim, hidden_dim, nn.BatchNorm1d(hidden_dim), nn.ReLU()),
            (hidden_dim, hidden_dim, nn.BatchNorm1d(hidden_dim), nn.ReLU()),
            (hidden_dim, output_dim, None, None),
        ])

# %%
class BarlowTwins(nn.Module):
    def __init__(self,
                 num_ftrs: int = 10,
                 proj_hidden_dim: int = 20,
                 out_dim: int = 40):

        super(BarlowTwins, self).__init__()

        self.num_ftrs = num_ftrs
        self.proj_hidden_dim = proj_hidden_dim
        self.out_dim = out_dim

        self.projection_mlp = BarlowTwinsProjectionHead(
            num_ftrs,
            proj_hidden_dim,
            out_dim
        )


    def forward(self,
                x0: torch.Tensor,
                x1: torch.Tensor = None,
                return_features: bool = False):
        
        f0 = x0.flatten(start_dim=1)
        out0 = self.projection_mlp(f0)

        if return_features:
            out0 = (out0, f0)

        if x1 is None:
            return out0

        f1 = x1.flatten(start_dim=1)
        out1 = self.projection_mlp(f1)

        if return_features:
            out1 = (out1, f1)

        return out0, out1

# %%
class BarlowTwinsLoss(torch.nn.Module):
    def __init__(
        self, 
        lambda_param: float = 5e-3, 
        gather_distributed : bool = False
    ):

        super(BarlowTwinsLoss, self).__init__()
        self.lambda_param = lambda_param
        self.gather_distributed = gather_distributed

    def forward(self, z_a: torch.Tensor, z_b: torch.Tensor) -> torch.Tensor:

        device = z_a.device

        z_a_norm = (z_a - z_a.mean(0)) / z_a.std(0)
        z_b_norm = (z_b - z_b.mean(0)) / z_b.std(0)

        N = z_a.size(0)
        D = z_a.size(1)

        c = torch.mm(z_a_norm.T, z_b_norm) / N 

        if self.gather_distributed and dist.is_initialized():
            world_size = dist.get_world_size()
            if world_size > 1:
                c = c / world_size
                dist.all_reduce(c)

        c_diff = (c - torch.eye(D, device=device)).pow(2)
        c_diff[~torch.eye(D, dtype=bool)] *= self.lambda_param
        loss = c_diff.sum()

        return loss

# %%
class ResidualBlock(nn.Module):
    
    def __init__(self,
                 in_channels,
                 dilation_rate: int,
                 nb_filters: int,
                 kernel_size: int,
                 dropout_rate: float = 0, 
                 use_batch_norm: bool = False,
                 use_layer_norm: bool = False,
                 use_weight_norm: bool = False, 
                 training: bool = True):
        """Defines the residual block for the WaveNet TCN
        Args:
            dilation_rate: The dilation power of 2 we are using for this residual block
            nb_filters: The number of convolutional filters to use in this block
            kernel_size: The size of the convolutional kernel
            activation: The final activation used in o = Activation(x + F(x))
            dropout_rate: Float between 0 and 1. Fraction of the input units to drop.
        """

        self.dilation_rate = dilation_rate
        self.nb_filters = nb_filters
        self.kernel_size = kernel_size
        self.dropout_rate = dropout_rate
        # for causal padding
        self.padding = (self.kernel_size - 1) * self.dilation_rate
        
        self.use_batch_norm = use_batch_norm
        self.use_layer_norm = use_layer_norm
        self.use_weight_norm = use_weight_norm
        
        self.training = training

        super(ResidualBlock, self).__init__()
        
        self.conv_1 = nn.Conv1d(in_channels, self.nb_filters, self.kernel_size, 
                                padding=0, dilation=self.dilation_rate)        
        if self.use_weight_norm:
            weight_norm(self.conv_1) 
        self.bn_1 = nn.BatchNorm1d(self.nb_filters)
        self.ln_1 = nn.LayerNorm(self.nb_filters)              
        self.relu_1 = nn.ReLU()

        self.conv_2 = nn.Conv1d(self.nb_filters, self.nb_filters, self.kernel_size, 
                                padding=0, dilation=self.dilation_rate)        
        if self.use_weight_norm:
            weight_norm(self.conv_1)    
        self.bn_2 = nn.BatchNorm1d(self.nb_filters)
        self.ln_2 = nn.LayerNorm(self.nb_filters)              
        self.relu_2 = nn.ReLU()        
        
        self.conv_block = nn.Sequential()
        self.downsample = nn.Conv1d(in_channels, self.nb_filters, kernel_size=1) if in_channels != self.nb_filters else nn.Identity()
        
        self.relu = nn.ReLU()  
                
        self.init_weights()
        
        
    def init_weights(self):
        # in the realization, they use random normal initialization
        torch.nn.init.normal_(self.conv_1.weight, mean=0, std=0.05)
        torch.nn.init.zeros_(self.conv_1.bias)            
        
        torch.nn.init.normal_(self.conv_2.weight, mean=0, std=0.05)
        torch.nn.init.zeros_(self.conv_2.bias)            
        
        if isinstance(self.downsample, nn.Conv1d):         
            torch.nn.init.normal_(self.downsample.weight, mean=0, std=0.05)
            torch.nn.init.zeros_(self.downsample.bias)                    
            
    def forward(self, inp):
        # inp batch, channels, time
        ######################
        # do causal padding        
        out = F.pad(inp, (self.padding, 0))
        out = self.conv_1(out)
        
        if self.use_batch_norm:
            out = self.bn_1(out)
        elif self.use_layer_norm:
            out = self.ln_1(out)        
        out = self.relu_1(out)
        
        # spatial dropout
        out = out.permute(0, 2, 1)   # convert to [batch, time, channels]
        out = F.dropout2d(out, self.dropout_rate, training=self.training)        
        out = out.permute(0, 2, 1)   # back to [batch, channels, time]    
        
        #######################
        # do causal padding
        out = F.pad(out, (self.padding, 0))
        out = self.conv_2(out)
        if self.use_batch_norm:
            out = self.bn_2(out)
        elif self.use_layer_norm:
            out = self.ln_2(out)
        out = self.relu_2(out)            
        out = self.relu_2(out)    
        # spatial dropout
        # out batch, channels, time 
        
        out = out.permute(0, 2, 1)   # convert to [batch, time, channels]
        out = F.dropout2d(out, self.dropout_rate, training=self.training)
        out = out.permute(0, 2, 1)   # back to [batch, channels, time]            
        
        #######################        
        skip_out = self.downsample(inp)
        #######################
        res = self.relu(out + skip_out)
        return res, skip_out
    
# only causal padding
# only return sequence = True
    
class TCN(nn.Module):        
    def __init__(self,
                 in_channels=1,
                 nb_filters=64,
                 kernel_size=3,
                 nb_stacks=1,
                 dilations=(1, 2, 4, 8, 16, 32),
                 use_skip_connections=True,
                 dropout_rate=0.0, 
                 use_batch_norm: bool = False,
                 use_layer_norm: bool = False, 
                 use_weight_norm: bool = False):

        super(TCN, self).__init__()
        
        self.dropout_rate = dropout_rate
        self.use_skip_connections = use_skip_connections
        self.dilations = dilations
        self.nb_stacks = nb_stacks
        self.kernel_size = kernel_size
        self.nb_filters = nb_filters
        
        self.use_batch_norm = use_batch_norm
        self.use_layer_norm = use_layer_norm
        self.use_weight_norm = use_weight_norm
        self.in_channels = in_channels
        if self.use_batch_norm + self.use_layer_norm + self.use_weight_norm > 1:
            raise ValueError('Only one normalization can be specified at once.')        
        
        self.residual_blocks = []        
        res_block_filters = 0
        for s in range(self.nb_stacks):
            for i, d in enumerate(self.dilations):
                in_channels = self.in_channels if i + s == 0 else res_block_filters                
                res_block_filters = self.nb_filters[i] if isinstance(self.nb_filters, list) else self.nb_filters
                self.residual_blocks.append(ResidualBlock(in_channels=in_channels, 
                                                          dilation_rate=d,
                                                          nb_filters=res_block_filters,
                                                          kernel_size=self.kernel_size,
                                                          dropout_rate=self.dropout_rate, 
                                                          use_batch_norm=self.use_batch_norm,
                                                          use_layer_norm=self.use_layer_norm,
                                                          use_weight_norm=self.use_weight_norm))

        
        self.residual_blocks = nn.ModuleList(self.residual_blocks)
                                            
    def forward(self, inp):
        out = inp
        for layer in self.residual_blocks:
            out, skip_out = layer(out)
        if self.use_skip_connections:
            out = out + skip_out
        return out

########################### model #########################################
class Encoder(nn.Module):
    def __init__(self, c_in=1, nb_filters=64, kernel_size=4, 
                 dilations=[1,2,4,8], nb_stacks=2, n_steps=50, code_size=10, seq_len=100):       
        super(Encoder, self).__init__()        
        
        self.tcn_layer = TCN(in_channels=c_in, nb_filters=nb_filters, 
                             nb_stacks=nb_stacks, dilations=dilations, use_skip_connections=True, dropout_rate=0)
        
        self.fc1 = nn.Linear(nb_filters * seq_len, 2 * n_steps)  
        self.fc2 = nn.Linear(2 * n_steps, n_steps)    
        self.output_layer = nn.Linear(n_steps, code_size)           
        self.relu = nn.ReLU()
        
    def forward(self, x):
        out = x
        if len(out.shape) == 2:
            out = out.unsqueeze(1)
        out = self.tcn_layer(out)     
        out = out.flatten(1, 2)         
        out = self.relu(self.fc1(out)) 
        out = self.relu(self.fc2(out)) 
        out = self.output_layer(out)
        return out
    
########################### loss #########################################
def _cosine_simililarity_dim2(x, y):
    cos = nn.CosineSimilarity(dim=2, eps=1e-6)
    v = cos(x.unsqueeze(1), y.unsqueeze(0))
    return v    


################## PL wrapper ###############################################
class BTSCP_model(pl.LightningModule):
    def __init__(
        self,
        encoder: nn.Module,
        model: nn.Module,     
        train_dataset: Dataset, 
        test_dataset: Dataset, 
        batch_size: int = 64,        
        num_workers: int = 2,        
        temperature: float = 0.1, 
        lr: float = 1e-4,
        decay_steps: int = 1000, 
        window_1: int = 100,
        window_2: int = 100
    ) -> None:
        super().__init__()
        self.encoder = encoder
        self.model = model
        self.train_dataset = train_dataset
        self.test_dataset = test_dataset
        
        self.batch_size = batch_size
        self.num_workers = num_workers        
        
        self.temperature = temperature
        
        self.lr = lr
        self.decay_steps = decay_steps   
        
        self.window = window_1
        self.window_1 = window_1
        self.window_2 = window_2
        self.loss = BarlowTwinsLoss()

    def forward(self, inputs1: torch.Tensor, inputs2=None) -> torch.Tensor:
        inp1 = self.encoder(inputs1)
        inp2 = self.encoder(inputs2)
        return self.model(inp1, inp2)
    
    def pred(self, inputs):
        return self.encoder(inputs)
    
    def training_step(self, batch1, batch2):
       
        emb1, emb2 = self.forward(batch1.float(), batch2.float())

        loss = self.loss.forward(emb1, emb2)

        return loss
        
    def validation_step(self, batch1, batch2):

        emb1, emb2 = self.forward(batch1.float(), batch2.float())

        loss = self.loss.forward(emb1, emb2)

        return loss


    def configure_optimizers(self) -> torch.optim.Optimizer:
        opt = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        return opt

    def train_dataloader(self) -> DataLoader:
        return DataLoader(
            self.train_dataset, batch_size=self.batch_size, shuffle=True, num_workers=self.num_workers
        )

    def val_dataloader(self) -> DataLoader:
        return DataLoader(
            self.test_dataset, batch_size=self.batch_size, shuffle=False, num_workers=self.num_workers
        )
    def get_enc(self):
        return self.encoder
    
def _cosine_simililarity_dim1(x, y):
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)
    v = cos(x, y)
    return v

# %%
def random_crop(batch, WIN):
    tmp = batch[0][:,1:]
    l = torch.randint(0, WIN+1, (1,))
    l = max(l, int(0.8 * tmp.shape[1]))
    pos = torch.randint(0, WIN // 10, (1,))
    tmp = tmp[:, pos:l+1]
    tmp = F.pad(input=tmp, pad=(WIN - tmp.shape[1], 0), mode='constant', value=0)
    return tmp

# %%
def random_noise(batch, sigma=1):
    tmp = batch[0][:,1:]
    noise = torch.normal(0, sigma, size=tmp.shape)
    tmp += noise
    return tmp

# %%
enc = Encoder(code_size = CODE_SIZE, seq_len = WIN)
model = BarlowTwins(CODE_SIZE, 2*CODE_SIZE, 4*CODE_SIZE)

model = BTSCP_model(enc, model, train_ds, test_ds, batch_size=BATCH_SIZE, temperature=TEMP, lr=LR, decay_steps=decay_steps, window_1=WIN)
optimizer = model.configure_optimizers()

# %%
train_loader = model.train_dataloader()
val_loader = model.val_dataloader()

train_losses = []
val_losses = []

for epoch in tqdm(range(EPOCHS)):
    
    iteration = 0
    train_losses_iters = []

    
    for index, batch in enumerate(train_loader):
        aug1, aug2 = random_crop(batch, WIN), random_crop(batch, WIN)
        loss = model.training_step(aug1, aug2)
        train_losses_iters.append(float(loss))

        print("train_losses_iters", train_losses_iters[-1])

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        iteration += 1

        if not iteration % 50:
            model.eval()
            vall = []
            with torch.no_grad():
                for c, b in enumerate(val_loader):
                    aug1, aug2 = random_crop([b], WIN), random_crop([b], WIN)
                    val_loss = model.validation_step(aug1, aug2)
                    vall.append(float(val_loss.detach()))
                    if c>10:
                        break
                print("val_loss", np.mean(vall))
                val_losses.append(np.mean(vall))
          
            
            model.train()
        
    print("epoch_train_loss", np.mean(train_losses_iters))  
    train_losses.append(np.mean(train_losses_iters))
    if len(val_losses):
        print("epoch_val_loss", np.mean(val_losses))
# Out:
# /home/bogdan/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|                                                    | 0/40 [00:00<?, ?it/s]/home/bogdan/.local/lib/python3.10/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
# train_losses_iters 24.186826705932617
# train_losses_iters 2.035172462463379
# train_losses_iters 1.9536380767822266
# train_losses_iters 25.047222137451172
# train_losses_iters 2.090066909790039
# train_losses_iters 2.0098931789398193
# train_losses_iters 2.02724552154541
# train_losses_iters 1.8167611360549927
# train_losses_iters 2.1229002475738525
# train_losses_iters 34.95899200439453
# train_losses_iters 2.5307252407073975
# train_losses_iters 27.999502182006836
# train_losses_iters 12.878658294677734
# train_losses_iters 2.2299301624298096
# train_losses_iters 2.751626968383789
# train_losses_iters 26.711463928222656
# train_losses_iters 2.1358089447021484
# train_losses_iters 2.435905933380127
# train_losses_iters 1.854870319366455
# train_losses_iters 3.178393602371216
# train_losses_iters 3.9356865882873535
# train_losses_iters 12.22683048248291
# train_losses_iters 23.78879165649414
# train_losses_iters 2.4218716621398926
# train_losses_iters 1.478054165840149
# train_losses_iters 3.116790294647217
# train_losses_iters 1.7452744245529175
# train_losses_iters 2.0647661685943604
# train_losses_iters 2.05324387550354
# train_losses_iters 20.543777465820312
# train_losses_iters 2.1908717155456543
# train_losses_iters 1.6673258543014526
# train_losses_iters 1.9545516967773438
# train_losses_iters 17.313743591308594
# train_losses_iters 1.972529411315918
# train_losses_iters 2.2507975101470947
# train_losses_iters 9.260912895202637
# train_losses_iters 1.700339436531067
# train_losses_iters 2.2919180393218994
# train_losses_iters 2.9256961345672607
# train_losses_iters 2.0466461181640625
# train_losses_iters 2.120137929916382
# train_losses_iters 1.6345343589782715
# train_losses_iters 2.017538070678711
# train_losses_iters 14.337719917297363
# train_losses_iters 1.768599271774292
# train_losses_iters 1.958181381225586
# train_losses_iters 32.79176712036133
# train_losses_iters 34.19675827026367
# train_losses_iters 3.9704129695892334
# val_loss 17.643020888169605
# train_losses_iters 2.9125466346740723
# train_losses_iters 29.953109741210938
# train_losses_iters 1.9256621599197388
# train_losses_iters 1.636216640472412
# train_losses_iters 3.5071969032287598
# train_losses_iters 2.3269827365875244
# train_losses_iters 1.9234614372253418
# train_losses_iters 5.923871994018555
# train_losses_iters 1.7674353122711182
# train_losses_iters 18.09804344177246
# train_losses_iters 2.2322936058044434
# train_losses_iters 2.476209878921509
# train_losses_iters 9.545303344726562
# train_losses_iters 30.302518844604492
# train_losses_iters 3.6314642429351807
# train_losses_iters 2.1135146617889404
# train_losses_iters 2.238136053085327
# train_losses_iters 2.348025321960449
# train_losses_iters 2.052673816680908
# train_losses_iters 2.151867389678955
# train_losses_iters 2.356210708618164
# train_losses_iters 2.3028228282928467
# train_losses_iters 1.9281328916549683
# train_losses_iters 2.1237359046936035
# train_losses_iters 9.498222351074219
# train_losses_iters 27.605152130126953
# train_losses_iters 25.420970916748047
# train_losses_iters 30.331689834594727
# train_losses_iters 30.424285888671875
# train_losses_iters 2.792870283126831
# train_losses_iters 2.122133493423462
# train_losses_iters 2.517279624938965
# train_losses_iters 2.3566126823425293
# train_losses_iters 6.256829261779785
# train_losses_iters 2.9143011569976807
# train_losses_iters 2.2080304622650146
# train_losses_iters 20.728805541992188
# train_losses_iters 24.602529525756836
# train_losses_iters 33.31890106201172
# train_losses_iters 2.9476423263549805
# train_losses_iters 14.137739181518555
# train_losses_iters 1.6118929386138916
# train_losses_iters 2.6669435501098633
# train_losses_iters 13.158143043518066
# train_losses_iters 2.3451058864593506
# train_losses_iters 3.2246158123016357
# train_losses_iters 2.981027364730835
# train_losses_iters 2.428443670272827
# train_losses_iters 29.04332733154297
# train_losses_iters 2.9399795532226562
# val_loss 20.918333689371746
# train_losses_iters 29.884096145629883
# train_losses_iters 1.8597917556762695
# train_losses_iters 2.2461400032043457
# train_losses_iters 1.7262043952941895
# train_losses_iters 18.203386306762695
# train_losses_iters 2.3316102027893066
# train_losses_iters 17.297607421875
# train_losses_iters 4.024267673492432
# train_losses_iters 2.268312454223633
# train_losses_iters 1.9284049272537231
# train_losses_iters 22.333951950073242
# train_losses_iters 2.269538640975952
# train_losses_iters 2.9716246128082275
# train_losses_iters 9.459245681762695
# train_losses_iters 23.594724655151367
# train_losses_iters 2.355097532272339
# train_losses_iters 19.977367401123047
#   2%|█                                           | 1/40 [00:42<27:51, 42.86s/it]
# epoch_train_loss 8.545247483457256
# epoch_val_loss 19.280677288770676
# train_losses_iters 2.06050968170166
# train_losses_iters 2.8866240978240967
# train_losses_iters 30.311492919921875
# train_losses_iters 2.037013530731201
# train_losses_iters 2.2524216175079346
# train_losses_iters 1.470069169998169
# train_losses_iters 1.9341477155685425
# train_losses_iters 2.325690269470215
# train_losses_iters 2.1072514057159424
# train_losses_iters 27.172317504882812
# train_losses_iters 24.776836395263672
# train_losses_iters 1.9360636472702026
# train_losses_iters 21.571063995361328
# train_losses_iters 2.3894832134246826
# train_losses_iters 2.887561559677124
# train_losses_iters 22.764022827148438
# train_losses_iters 2.347937822341919
# train_losses_iters 2.4910688400268555
# train_losses_iters 21.184417724609375
# train_losses_iters 1.5194916725158691
# train_losses_iters 5.592536449432373
# train_losses_iters 2.3087263107299805
# train_losses_iters 4.802385330200195
# train_losses_iters 3.462223529815674
# train_losses_iters 18.96099281311035
# train_losses_iters 2.7402679920196533
# train_losses_iters 2.4898672103881836
# train_losses_iters 24.09050750732422
# train_losses_iters 2.224609851837158
# train_losses_iters 2.388202428817749
# train_losses_iters 18.44504165649414
# train_losses_iters 25.151657104492188
# train_losses_iters 2.6384196281433105
# train_losses_iters 3.0113365650177
# train_losses_iters 1.860466480255127
# train_losses_iters 2.0811004638671875
# train_losses_iters 28.881183624267578
# train_losses_iters 17.025753021240234
# train_losses_iters 2.055227279663086
# train_losses_iters 3.9729366302490234
# train_losses_iters 2.238999843597412
# train_losses_iters 2.100341320037842
# train_losses_iters 23.24683380126953
# train_losses_iters 21.04621696472168
# train_losses_iters 2.6988086700439453
# train_losses_iters 2.9822113513946533
# train_losses_iters 20.55565643310547
# train_losses_iters 3.1815950870513916
# train_losses_iters 13.896478652954102
# train_losses_iters 1.9748014211654663
# val_loss 9.29051739970843
# train_losses_iters 2.5802230834960938
# train_losses_iters 1.9008673429489136
# train_losses_iters 34.05989074707031
# train_losses_iters 2.776597738265991
# train_losses_iters 2.016676664352417
# train_losses_iters 2.5075252056121826
# train_losses_iters 18.877700805664062
# train_losses_iters 16.88401222229004
# train_losses_iters 1.7600905895233154
# train_losses_iters 10.031092643737793
# train_losses_iters 1.7858266830444336
# train_losses_iters 2.8722786903381348
# train_losses_iters 2.34911847114563
# train_losses_iters 19.472949981689453
# train_losses_iters 2.7530360221862793
# train_losses_iters 2.762528419494629
# train_losses_iters 13.51621150970459
# train_losses_iters 1.9288791418075562
# train_losses_iters 3.6105966567993164
# train_losses_iters 15.592984199523926
# train_losses_iters 2.46600079536438
# train_losses_iters 2.6018497943878174
# train_losses_iters 9.842002868652344
# train_losses_iters 10.490434646606445
# train_losses_iters 2.5383477210998535
# train_losses_iters 2.7836742401123047
# train_losses_iters 2.6811931133270264
# train_losses_iters 3.213874578475952
# train_losses_iters 1.922306776046753
# train_losses_iters 4.048482894897461
# train_losses_iters 2.403409481048584
# train_losses_iters 19.440200805664062
# train_losses_iters 2.6035642623901367
# train_losses_iters 22.59206199645996
# train_losses_iters 18.59029769897461
# train_losses_iters 2.5078201293945312
# train_losses_iters 16.943378448486328
# train_losses_iters 19.325759887695312
# train_losses_iters 3.4990832805633545
# train_losses_iters 6.994821071624756
# train_losses_iters 2.8657584190368652
# train_losses_iters 4.734533309936523
# train_losses_iters 3.0986833572387695
# train_losses_iters 20.00182342529297
# train_losses_iters 26.784393310546875
# train_losses_iters 2.5609891414642334
# train_losses_iters 20.007225036621094
# train_losses_iters 25.27849578857422
# train_losses_iters 19.399154663085938
# train_losses_iters 2.9004859924316406
# val_loss 16.410721133152645
# train_losses_iters 2.7393550872802734
# train_losses_iters 20.550649642944336
# train_losses_iters 3.022083282470703
# train_losses_iters 2.6902105808258057
# train_losses_iters 2.9255621433258057
# train_losses_iters 20.650211334228516
# train_losses_iters 2.628645658493042
# train_losses_iters 2.7517776489257812
# train_losses_iters 2.1471190452575684
# train_losses_iters 2.4991235733032227
# train_losses_iters 3.0139729976654053
# train_losses_iters 2.1841812133789062
# train_losses_iters 5.338872909545898
# train_losses_iters 11.533092498779297
# train_losses_iters 2.063650608062744
# train_losses_iters 5.648105621337891
#   5%|██▏                                         | 2/40 [01:24<26:50, 42.37s/it]
# train_losses_iters 3.4211182594299316
# epoch_train_loss 8.440152110197605
# epoch_val_loss 16.065648277600605
# train_losses_iters 3.2537178993225098
# train_losses_iters 3.3900046348571777
# train_losses_iters 2.4049487113952637
# train_losses_iters 1.87126886844635
# train_losses_iters 3.011547088623047
# train_losses_iters 2.5354323387145996
# train_losses_iters 2.920548915863037
# train_losses_iters 3.7344322204589844
# train_losses_iters 2.4095873832702637
# train_losses_iters 17.168779373168945
# train_losses_iters 2.311999559402466
# train_losses_iters 15.579673767089844
# train_losses_iters 2.4015450477600098
# train_losses_iters 24.7304744720459
# train_losses_iters 15.92808723449707
# train_losses_iters 9.90612506866455
# train_losses_iters 2.7399702072143555
# train_losses_iters 2.0201637744903564
# train_losses_iters 13.13371753692627
# train_losses_iters 2.258981704711914
# train_losses_iters 11.269511222839355
# train_losses_iters 2.2363929748535156
# train_losses_iters 27.55014991760254
# train_losses_iters 2.9999475479125977
# train_losses_iters 2.7285139560699463
# train_losses_iters 2.5730409622192383
# train_losses_iters 3.0530288219451904
# train_losses_iters 3.2786803245544434
# train_losses_iters 3.023409366607666
# train_losses_iters 26.870054244995117
# train_losses_iters 2.5017497539520264
# train_losses_iters 2.426138401031494
# train_losses_iters 20.506290435791016
# train_losses_iters 3.0951781272888184
# train_losses_iters 2.509406089782715
# train_losses_iters 2.5270586013793945
# train_losses_iters 3.192153215408325
# train_losses_iters 2.304919719696045
# train_losses_iters 3.2687175273895264
# train_losses_iters 16.64066505432129
# train_losses_iters 2.7126030921936035
# train_losses_iters 24.809961318969727
# train_losses_iters 2.878108501434326
# train_losses_iters 2.656934976577759
# train_losses_iters 11.942415237426758
# train_losses_iters 19.756004333496094
# train_losses_iters 3.1083664894104004
# train_losses_iters 2.639373540878296
# train_losses_iters 17.469058990478516
# train_losses_iters 18.093286514282227
# val_loss 10.368733823299408
# train_losses_iters 2.903355836868286
# train_losses_iters 2.7971765995025635
# train_losses_iters 2.4884958267211914
# train_losses_iters 5.446173667907715
# train_losses_iters 1.671278715133667
# train_losses_iters 26.278345108032227
# train_losses_iters 14.146961212158203
# train_losses_iters 6.674797534942627
# train_losses_iters 2.1547489166259766
# train_losses_iters 4.034764289855957
# train_losses_iters 2.6306002140045166
# train_losses_iters 13.579591751098633
# train_losses_iters 3.1408417224884033
# train_losses_iters 2.793285369873047
# train_losses_iters 3.202559471130371
# train_losses_iters 3.168466806411743
# train_losses_iters 14.96732234954834
# train_losses_iters 2.807713508605957
# train_losses_iters 1.9512193202972412
# train_losses_iters 20.817256927490234
# train_losses_iters 3.0598196983337402
# train_losses_iters 9.64007568359375
# train_losses_iters 3.1298632621765137
# train_losses_iters 2.702639102935791
# train_losses_iters 18.530719757080078
# train_losses_iters 2.7901206016540527
# train_losses_iters 3.5550527572631836
# train_losses_iters 2.3002874851226807
# train_losses_iters 2.3328537940979004
# train_losses_iters 3.071584701538086
# train_losses_iters 4.903048038482666
# train_losses_iters 2.7161266803741455
# train_losses_iters 17.477638244628906
# train_losses_iters 3.9065728187561035
# train_losses_iters 9.93551254272461
# train_losses_iters 2.4316163063049316
# train_losses_iters 2.7714438438415527
# train_losses_iters 25.802398681640625
# train_losses_iters 13.26256275177002
# train_losses_iters 2.354719400405884
# train_losses_iters 2.528374671936035
# train_losses_iters 8.644963264465332
# train_losses_iters 3.5796871185302734
# train_losses_iters 15.52755355834961
# train_losses_iters 6.658159255981445
# train_losses_iters 2.8415026664733887
# train_losses_iters 7.580916404724121
# train_losses_iters 2.6446571350097656
# train_losses_iters 3.3885226249694824
# train_losses_iters 3.2477152347564697
# val_loss 9.238408863544464
# train_losses_iters 7.982740879058838
# train_losses_iters 2.482116222381592
# train_losses_iters 13.779314041137695
# train_losses_iters 3.207961082458496
# train_losses_iters 21.74384880065918
# train_losses_iters 6.550887107849121
# train_losses_iters 16.391359329223633
# train_losses_iters 1.9284335374832153
# train_losses_iters 3.009213447570801
# train_losses_iters 3.0153260231018066
# train_losses_iters 3.533738851547241
# train_losses_iters 19.802248001098633
# train_losses_iters 15.72532844543457
# train_losses_iters 2.459249258041382
# train_losses_iters 2.3478381633758545
# train_losses_iters 2.767364978790283
# train_losses_iters 2.2397830486297607
#   8%|███▎                                        | 3/40 [01:56<23:10, 37.59s/it]
# epoch_train_loss 7.215987517283513
# epoch_val_loss 13.978289299541048
# train_losses_iters 9.061591148376465
# train_losses_iters 11.86021900177002
# train_losses_iters 11.599929809570312
# train_losses_iters 2.9801719188690186
# train_losses_iters 6.760810375213623
# train_losses_iters 3.110388994216919
# train_losses_iters 2.745880365371704
# train_losses_iters 9.831634521484375
# train_losses_iters 2.571290969848633
# train_losses_iters 2.8855299949645996
# train_losses_iters 2.49623966217041
# train_losses_iters 2.6220664978027344
# train_losses_iters 2.694453001022339
# train_losses_iters 2.626347064971924
# train_losses_iters 23.39451789855957
# train_losses_iters 3.255992889404297
# train_losses_iters 13.220993995666504
# train_losses_iters 3.3510489463806152
# train_losses_iters 2.7772321701049805
# train_losses_iters 22.020488739013672
# train_losses_iters 24.94925880432129
# train_losses_iters 1.8689969778060913
# train_losses_iters 23.54478645324707
# train_losses_iters 3.4191553592681885
# train_losses_iters 13.576861381530762
# train_losses_iters 10.032405853271484
# train_losses_iters 2.6319587230682373
# train_losses_iters 19.14289665222168
# train_losses_iters 2.8183157444000244
# train_losses_iters 3.1301937103271484
# train_losses_iters 3.881730079650879
# train_losses_iters 9.652833938598633
# train_losses_iters 4.230739116668701
# train_losses_iters 2.67732572555542
# train_losses_iters 3.8117494583129883
# train_losses_iters 2.8171498775482178
# train_losses_iters 4.060349464416504
# train_losses_iters 24.166290283203125
# train_losses_iters 22.036306381225586
# train_losses_iters 2.935577154159546
# train_losses_iters 3.2692108154296875
# train_losses_iters 2.9122557640075684
# train_losses_iters 6.170686721801758
# train_losses_iters 3.361138343811035
# train_losses_iters 2.8624520301818848
# train_losses_iters 2.6419527530670166
# train_losses_iters 2.550173282623291
# train_losses_iters 2.462552547454834
# train_losses_iters 2.884381055831909
# train_losses_iters 2.855833053588867
# val_loss 7.8624307513237
# train_losses_iters 7.7108588218688965
# train_losses_iters 2.5660228729248047
# train_losses_iters 3.1042044162750244
# train_losses_iters 3.008622407913208
# train_losses_iters 9.749353408813477
# train_losses_iters 2.689114809036255
# train_losses_iters 3.0354490280151367
# train_losses_iters 10.527289390563965
# train_losses_iters 3.65692138671875
# train_losses_iters 2.630366325378418
# train_losses_iters 23.399686813354492
# train_losses_iters 18.519039154052734
# train_losses_iters 2.8564765453338623
# train_losses_iters 10.29649543762207
# train_losses_iters 2.860177516937256
# train_losses_iters 2.3514304161071777
# train_losses_iters 14.76290512084961
# train_losses_iters 2.8268043994903564
# train_losses_iters 22.974735260009766
# train_losses_iters 3.6306982040405273
# train_losses_iters 3.468507766723633
# train_losses_iters 3.4495348930358887
# train_losses_iters 17.29092788696289
# train_losses_iters 3.0713577270507812
# train_losses_iters 16.691987991333008
# train_losses_iters 15.678499221801758
# train_losses_iters 2.475156784057617
# train_losses_iters 18.70327377319336
# train_losses_iters 2.695537805557251
# train_losses_iters 2.9888477325439453
# train_losses_iters 19.9879093170166
# train_losses_iters 23.048738479614258
# train_losses_iters 2.9295735359191895
# train_losses_iters 2.868431568145752
# train_losses_iters 2.8884410858154297
# train_losses_iters 15.186447143554688
# train_losses_iters 2.3971900939941406
# train_losses_iters 3.6607747077941895
# train_losses_iters 10.961844444274902
# train_losses_iters 2.9337832927703857
# train_losses_iters 2.865814208984375
# train_losses_iters 3.608368158340454
# train_losses_iters 3.1776812076568604
# train_losses_iters 2.3747899532318115
# train_losses_iters 14.77352237701416
# train_losses_iters 3.1853935718536377
# train_losses_iters 2.749091625213623
# train_losses_iters 2.402113676071167
# train_losses_iters 16.20286750793457
# train_losses_iters 16.267141342163086
# val_loss 15.079366068045298
# train_losses_iters 2.796269178390503
# train_losses_iters 3.3835132122039795
# train_losses_iters 17.63572120666504
# train_losses_iters 4.784956932067871
# train_losses_iters 11.424468040466309
# train_losses_iters 3.1042368412017822
# train_losses_iters 2.6880102157592773
# train_losses_iters 3.290705442428589
# train_losses_iters 10.23224925994873
# train_losses_iters 23.775672912597656
# train_losses_iters 3.190478801727295
# train_losses_iters 2.8061671257019043
# train_losses_iters 2.555281400680542
# train_losses_iters 19.570049285888672
# train_losses_iters 3.3486595153808594
# train_losses_iters 17.582674026489258
# train_losses_iters 5.015227794647217
#  10%|████▍                                       | 4/40 [02:24<20:18, 33.86s/it]
# epoch_train_loss 7.611511857081682
# epoch_val_loss 13.351441577076912
# train_losses_iters 1.8598392009735107
# train_losses_iters 12.880752563476562
# train_losses_iters 3.3306102752685547
# train_losses_iters 2.933767318725586
# train_losses_iters 2.997030019760132
# train_losses_iters 15.032461166381836
# train_losses_iters 3.1313891410827637
# train_losses_iters 3.107300043106079
# train_losses_iters 2.857573986053467
# train_losses_iters 14.963922500610352
# train_losses_iters 8.608190536499023
# train_losses_iters 13.012918472290039
# train_losses_iters 8.841434478759766
# train_losses_iters 2.978405237197876
# train_losses_iters 2.6690351963043213
# train_losses_iters 3.6412394046783447
# train_losses_iters 2.7409627437591553
# train_losses_iters 6.533721446990967
# train_losses_iters 10.990957260131836
# train_losses_iters 21.09947967529297
# train_losses_iters 3.3784584999084473
# train_losses_iters 18.930801391601562
# train_losses_iters 3.845104217529297
# train_losses_iters 9.559860229492188
# train_losses_iters 2.4923739433288574
# train_losses_iters 12.085552215576172
# train_losses_iters 13.054754257202148
# train_losses_iters 14.006986618041992
# train_losses_iters 4.957038402557373
# train_losses_iters 5.295165061950684
# train_losses_iters 3.716445207595825
# train_losses_iters 10.811086654663086
# train_losses_iters 5.947920799255371
# train_losses_iters 2.8689022064208984
# train_losses_iters 3.7050561904907227
# train_losses_iters 10.207723617553711
# train_losses_iters 3.381617546081543
# train_losses_iters 4.519057750701904
# train_losses_iters 2.787228584289551
# train_losses_iters 3.037583112716675
# train_losses_iters 7.716067314147949
# train_losses_iters 2.5934464931488037
# train_losses_iters 3.085724115371704
# train_losses_iters 2.9182350635528564
# train_losses_iters 4.098781108856201
# train_losses_iters 15.006750106811523
# train_losses_iters 3.9479317665100098
# train_losses_iters 2.777462959289551
# train_losses_iters 19.25079917907715
# train_losses_iters 2.8820993900299072
# val_loss 21.379229694604874
# train_losses_iters 3.657825469970703
# train_losses_iters 2.8303170204162598
# train_losses_iters 3.7724738121032715
# train_losses_iters 4.932343482971191
# train_losses_iters 16.26405143737793
# train_losses_iters 14.782608032226562
# train_losses_iters 2.4482741355895996
# train_losses_iters 11.402023315429688
# train_losses_iters 12.264813423156738
# train_losses_iters 3.647167682647705
# train_losses_iters 12.762718200683594
# train_losses_iters 19.251205444335938
# train_losses_iters 3.0359296798706055
# train_losses_iters 2.958416223526001
# train_losses_iters 3.1107821464538574
# train_losses_iters 10.809920310974121
# train_losses_iters 17.605022430419922
# train_losses_iters 9.471323013305664
# train_losses_iters 2.286750078201294
# train_losses_iters 3.1670780181884766
# train_losses_iters 13.714249610900879
# train_losses_iters 2.844003200531006
# train_losses_iters 9.174328804016113
# train_losses_iters 3.0974488258361816
# train_losses_iters 3.825218677520752
# train_losses_iters 6.052094459533691
# train_losses_iters 7.39626407623291
# train_losses_iters 17.94032096862793
# train_losses_iters 4.388612270355225
# train_losses_iters 3.626697540283203
# train_losses_iters 15.523836135864258
# train_losses_iters 2.6398813724517822
# train_losses_iters 20.298999786376953
# train_losses_iters 7.638917922973633
# train_losses_iters 2.7622103691101074
# train_losses_iters 15.852254867553711
# train_losses_iters 3.172666072845459
# train_losses_iters 3.174736261367798
# train_losses_iters 18.27132797241211
# train_losses_iters 3.2084174156188965
# train_losses_iters 13.770760536193848
# train_losses_iters 3.5126168727874756
# train_losses_iters 3.548145294189453
# train_losses_iters 2.736419916152954
# train_losses_iters 4.932570934295654
# train_losses_iters 3.4515011310577393
# train_losses_iters 3.5905909538269043
# train_losses_iters 3.215165615081787
# train_losses_iters 2.701521396636963
# train_losses_iters 12.400317192077637
# val_loss 13.493654390176138
# train_losses_iters 2.699251651763916
# train_losses_iters 2.5447869300842285
# train_losses_iters 3.138425350189209
# train_losses_iters 2.430941343307495
# train_losses_iters 2.30145263671875
# train_losses_iters 3.194551467895508
# train_losses_iters 11.49209976196289
# train_losses_iters 2.982550621032715
# train_losses_iters 3.543942451477051
# train_losses_iters 3.2917094230651855
# train_losses_iters 2.4593942165374756
# train_losses_iters 3.5871479511260986
# train_losses_iters 3.0863282680511475
# train_losses_iters 2.793707847595215
# train_losses_iters 3.0184762477874756
# train_losses_iters 2.77406907081604
#  12%|█████▌                                      | 5/40 [02:52<18:22, 31.51s/it]
# train_losses_iters 6.469751358032227
# epoch_train_loss 6.733407957941039
# epoch_val_loss 14.168441670139632
# train_losses_iters 8.429672241210938
# train_losses_iters 2.9671802520751953
# train_losses_iters 3.352919101715088
# train_losses_iters 13.53722095489502
# train_losses_iters 3.438016653060913
# train_losses_iters 3.642367362976074
# train_losses_iters 2.909149408340454
# train_losses_iters 2.9081618785858154
# train_losses_iters 2.8847551345825195
# train_losses_iters 6.095270156860352
# train_losses_iters 3.9322056770324707
# train_losses_iters 9.002985954284668
# train_losses_iters 3.2032065391540527
# train_losses_iters 17.493497848510742
# train_losses_iters 3.5741846561431885
# train_losses_iters 3.4485397338867188
# train_losses_iters 16.167034149169922
# train_losses_iters 3.4428510665893555
# train_losses_iters 2.9095613956451416
# train_losses_iters 13.113504409790039
# train_losses_iters 15.9176025390625
# train_losses_iters 3.2698757648468018
# train_losses_iters 2.975961208343506
# train_losses_iters 3.038504123687744
# train_losses_iters 3.2751212120056152
# train_losses_iters 3.2829694747924805
# train_losses_iters 10.871397972106934
# train_losses_iters 2.8998703956604004
# train_losses_iters 2.7291483879089355
# train_losses_iters 10.964719772338867
# train_losses_iters 18.208845138549805
# train_losses_iters 3.320223808288574
# train_losses_iters 10.517066955566406
# train_losses_iters 3.760895252227783
# train_losses_iters 3.6245107650756836
# train_losses_iters 3.814570665359497
# train_losses_iters 3.0301218032836914
# train_losses_iters 15.42508602142334
# train_losses_iters 18.28173065185547
# train_losses_iters 21.56560516357422
# train_losses_iters 14.298097610473633
# train_losses_iters 19.91961669921875
# train_losses_iters 3.6321403980255127
# train_losses_iters 3.1064252853393555
# train_losses_iters 7.710710525512695
# train_losses_iters 3.111738681793213
# train_losses_iters 2.9336957931518555
# train_losses_iters 3.527174234390259
# train_losses_iters 2.634286880493164
# train_losses_iters 4.668272018432617
# val_loss 20.53261399269104
# train_losses_iters 7.108861923217773
# train_losses_iters 12.96021842956543
# train_losses_iters 9.440593719482422
# train_losses_iters 6.631668567657471
# train_losses_iters 3.853733777999878
# train_losses_iters 3.0809640884399414
# train_losses_iters 3.4830074310302734
# train_losses_iters 3.489417314529419
# train_losses_iters 3.508702039718628
# train_losses_iters 16.14038848876953
# train_losses_iters 2.8597917556762695
# train_losses_iters 2.6011903285980225
# train_losses_iters 3.6046626567840576
# train_losses_iters 10.7359037399292
# train_losses_iters 3.860215425491333
# train_losses_iters 3.5319998264312744
# train_losses_iters 18.074169158935547
# train_losses_iters 14.70865249633789
# train_losses_iters 14.540614128112793
# train_losses_iters 3.1556859016418457
# train_losses_iters 11.119413375854492
# train_losses_iters 12.41419506072998
# train_losses_iters 3.048626184463501
# train_losses_iters 3.695516586303711
# train_losses_iters 4.38286828994751
# train_losses_iters 3.2469918727874756
# train_losses_iters 3.153778314590454
# train_losses_iters 3.203272819519043
# train_losses_iters 3.261385917663574
# train_losses_iters 4.007243633270264
# train_losses_iters 3.792963981628418
# train_losses_iters 3.712416172027588
# train_losses_iters 3.8308115005493164
# train_losses_iters 3.2580339908599854
# train_losses_iters 15.956153869628906
# train_losses_iters 3.818788766860962
# train_losses_iters 16.478303909301758
# train_losses_iters 3.5621755123138428
# train_losses_iters 3.7947471141815186
# train_losses_iters 3.3042662143707275
# train_losses_iters 14.884540557861328
# train_losses_iters 3.574709177017212
# train_losses_iters 5.045038223266602
# train_losses_iters 3.047395944595337
# train_losses_iters 3.5301804542541504
# train_losses_iters 15.693012237548828
# train_losses_iters 3.2381539344787598
# train_losses_iters 3.5020246505737305
# train_losses_iters 2.079286575317383
# train_losses_iters 10.593579292297363
# val_loss 12.460991531610489
# train_losses_iters 3.426586627960205
# train_losses_iters 3.1046462059020996
# train_losses_iters 2.7644848823547363
# train_losses_iters 11.270095825195312
# train_losses_iters 3.304781198501587
# train_losses_iters 3.437788963317871
# train_losses_iters 3.6333844661712646
# train_losses_iters 3.561776638031006
# train_losses_iters 3.2672536373138428
# train_losses_iters 2.8631725311279297
# train_losses_iters 2.982419967651367
# train_losses_iters 2.9830708503723145
# train_losses_iters 3.2931442260742188
# train_losses_iters 3.1190686225891113
# train_losses_iters 3.7284624576568604
# train_losses_iters 3.894171953201294
# train_losses_iters 3.6872141361236572
#  15%|██████▌                                     | 6/40 [03:19<16:57, 29.91s/it]
# epoch_train_loss 6.347778703412439
# epoch_val_loss 14.556501852141487
# train_losses_iters 6.501483917236328
# train_losses_iters 3.6117634773254395
# train_losses_iters 3.70906925201416
# train_losses_iters 3.2263917922973633
# train_losses_iters 3.2231650352478027
# train_losses_iters 3.9014205932617188
# train_losses_iters 2.5736773014068604
# train_losses_iters 4.83477258682251
# train_losses_iters 14.32259750366211
# train_losses_iters 2.688373565673828
# train_losses_iters 3.358596086502075
# train_losses_iters 3.1694579124450684
# train_losses_iters 4.1912713050842285
# train_losses_iters 3.204782247543335
# train_losses_iters 3.438539505004883
# train_losses_iters 3.967707633972168
# train_losses_iters 4.819936752319336
# train_losses_iters 6.339662551879883
# train_losses_iters 3.8797621726989746
# train_losses_iters 2.5868301391601562
# train_losses_iters 2.3716766834259033
# train_losses_iters 2.694139242172241
# train_losses_iters 3.425144672393799
# train_losses_iters 2.6733689308166504
# train_losses_iters 3.463071584701538
# train_losses_iters 2.992255449295044
# train_losses_iters 2.632195472717285
# train_losses_iters 9.201274871826172
# train_losses_iters 2.8438198566436768
# train_losses_iters 14.798312187194824
# train_losses_iters 14.407416343688965
# train_losses_iters 4.383905410766602
# train_losses_iters 3.8391377925872803
# train_losses_iters 3.1319122314453125
# train_losses_iters 3.4773354530334473
# train_losses_iters 5.685958385467529
# train_losses_iters 2.6148409843444824
# train_losses_iters 1.8114752769470215
# train_losses_iters 3.884337902069092
# train_losses_iters 15.925460815429688
# train_losses_iters 2.543020486831665
# train_losses_iters 18.888444900512695
# train_losses_iters 13.391667366027832
# train_losses_iters 14.29557991027832
# train_losses_iters 12.197656631469727
# train_losses_iters 3.3259665966033936
# train_losses_iters 9.696545600891113
# train_losses_iters 18.464723587036133
# train_losses_iters 10.719427108764648
# train_losses_iters 2.769897937774658
# val_loss 6.983113567034404
# train_losses_iters 14.240760803222656
# train_losses_iters 3.334348440170288
# train_losses_iters 3.0172765254974365
# train_losses_iters 3.2536063194274902
# train_losses_iters 3.573862075805664
# train_losses_iters 3.0613980293273926
# train_losses_iters 3.2476553916931152
# train_losses_iters 3.0446486473083496
# train_losses_iters 3.9531705379486084
# train_losses_iters 3.319908380508423
# train_losses_iters 3.1166348457336426
# train_losses_iters 3.560073137283325
# train_losses_iters 10.080479621887207
# train_losses_iters 7.583162307739258
# train_losses_iters 11.066341400146484
# train_losses_iters 11.031486511230469
# train_losses_iters 11.859277725219727
# train_losses_iters 3.2614102363586426
# train_losses_iters 3.6147170066833496
# train_losses_iters 2.657501459121704
# train_losses_iters 2.9553725719451904
# train_losses_iters 3.503298282623291
# train_losses_iters 3.465510368347168
# train_losses_iters 3.134294271469116
# train_losses_iters 2.6770944595336914
# train_losses_iters 3.532188653945923
# train_losses_iters 10.806146621704102
# train_losses_iters 3.891571044921875
# train_losses_iters 7.929033279418945
# train_losses_iters 3.736968994140625
# train_losses_iters 3.609323501586914
# train_losses_iters 12.686925888061523
# train_losses_iters 19.49942970275879
# train_losses_iters 3.4833223819732666
# train_losses_iters 3.200230598449707
# train_losses_iters 3.9219424724578857
# train_losses_iters 3.2447333335876465
# train_losses_iters 2.506615161895752
# train_losses_iters 2.552337169647217
# train_losses_iters 7.616236209869385
# train_losses_iters 4.49300479888916
# train_losses_iters 12.13926887512207
# train_losses_iters 3.980620861053467
# train_losses_iters 3.4181389808654785
# train_losses_iters 12.615094184875488
# train_losses_iters 11.56222915649414
# train_losses_iters 10.500662803649902
# train_losses_iters 3.671611785888672
# train_losses_iters 15.70724868774414
# train_losses_iters 15.260231018066406
# val_loss 7.472595443328221
# train_losses_iters 4.58367919921875
# train_losses_iters 3.381057024002075
# train_losses_iters 2.6179678440093994
# train_losses_iters 3.355405569076538
# train_losses_iters 13.131241798400879
# train_losses_iters 3.2189314365386963
# train_losses_iters 3.743455171585083
# train_losses_iters 3.5741372108459473
# train_losses_iters 3.59344744682312
# train_losses_iters 3.559826374053955
# train_losses_iters 14.02664852142334
# train_losses_iters 3.750194787979126
# train_losses_iters 2.9440836906433105
# train_losses_iters 4.005796432495117
# train_losses_iters 2.9681057929992676
# train_losses_iters 3.2722349166870117
# train_losses_iters 15.4764986038208
#  18%|███████▋                                    | 7/40 [03:45<15:51, 28.84s/it]
# epoch_train_loss 6.0211995585351925
# epoch_val_loss 13.509552231147177
# train_losses_iters 14.666553497314453
# train_losses_iters 3.6088874340057373
# train_losses_iters 2.7574973106384277
# train_losses_iters 13.378677368164062
# train_losses_iters 3.919072151184082
# train_losses_iters 14.381632804870605
# train_losses_iters 7.42237663269043
# train_losses_iters 4.005427360534668
# train_losses_iters 3.3271849155426025
# train_losses_iters 11.40428352355957
# train_losses_iters 12.8233060836792
# train_losses_iters 2.807730197906494
# train_losses_iters 13.60810661315918
# train_losses_iters 3.1838443279266357
# train_losses_iters 2.716235637664795
# train_losses_iters 5.512539386749268
# train_losses_iters 11.671655654907227
# train_losses_iters 3.366244316101074
# train_losses_iters 3.6097500324249268
# train_losses_iters 11.776006698608398
# train_losses_iters 3.457758665084839
# train_losses_iters 2.776244878768921
# train_losses_iters 3.026569366455078
# train_losses_iters 12.75052547454834
# train_losses_iters 12.594146728515625
# train_losses_iters 3.599118709564209
# train_losses_iters 3.2413015365600586
# train_losses_iters 11.774301528930664
# train_losses_iters 6.987705230712891
# train_losses_iters 3.1884915828704834
# train_losses_iters 10.126511573791504
# train_losses_iters 3.473111152648926
# train_losses_iters 3.8053014278411865
# train_losses_iters 3.1367087364196777
# train_losses_iters 4.1987481117248535
# train_losses_iters 12.37077522277832
# train_losses_iters 3.638174057006836
# train_losses_iters 9.695924758911133
# train_losses_iters 3.5331084728240967
# train_losses_iters 2.744929552078247
# train_losses_iters 2.968813419342041
# train_losses_iters 3.05281662940979
# train_losses_iters 3.2243213653564453
# train_losses_iters 3.023055076599121
# train_losses_iters 3.2256810665130615
# train_losses_iters 3.8250603675842285
# train_losses_iters 3.9823598861694336
# train_losses_iters 2.962963581085205
# train_losses_iters 3.916283130645752
# train_losses_iters 3.2949583530426025
# val_loss 18.087166885534923
# train_losses_iters 6.906700134277344
# train_losses_iters 2.9085779190063477
# train_losses_iters 2.6603665351867676
# train_losses_iters 2.7926039695739746
# train_losses_iters 12.10811996459961
# train_losses_iters 6.188056468963623
# train_losses_iters 3.9770328998565674
# train_losses_iters 11.820943832397461
# train_losses_iters 3.490999937057495
# train_losses_iters 13.289237022399902
# train_losses_iters 3.7553248405456543
# train_losses_iters 3.733039140701294
# train_losses_iters 13.548293113708496
# train_losses_iters 2.9290027618408203
# train_losses_iters 3.593637228012085
# train_losses_iters 3.241715908050537
# train_losses_iters 13.289981842041016
# train_losses_iters 3.0761630535125732
# train_losses_iters 3.4909980297088623
# train_losses_iters 3.854365110397339
# train_losses_iters 2.9959518909454346
# train_losses_iters 3.11189341545105
# train_losses_iters 12.858718872070312
# train_losses_iters 8.68466567993164
# train_losses_iters 5.643815040588379
# train_losses_iters 2.9087815284729004
# train_losses_iters 3.3758955001831055
# train_losses_iters 2.854102373123169
# train_losses_iters 2.855675220489502
# train_losses_iters 3.301931619644165
# train_losses_iters 11.938292503356934
# train_losses_iters 3.5702197551727295
# train_losses_iters 3.9339218139648438
# train_losses_iters 3.1692798137664795
# train_losses_iters 2.902765989303589
# train_losses_iters 8.546310424804688
# train_losses_iters 3.050015687942505
# train_losses_iters 4.28001070022583
# train_losses_iters 3.676056146621704
# train_losses_iters 2.485245704650879
# train_losses_iters 3.0777299404144287
# train_losses_iters 3.1609272956848145
# train_losses_iters 3.475489616394043
# train_losses_iters 2.854013442993164
# train_losses_iters 11.508652687072754
# train_losses_iters 10.070972442626953
# train_losses_iters 16.70130157470703
# train_losses_iters 2.9004883766174316
# train_losses_iters 3.575272798538208
# train_losses_iters 2.828514575958252
# val_loss 15.673307011524836
# train_losses_iters 2.5613608360290527
# train_losses_iters 3.1733436584472656
# train_losses_iters 3.132695436477661
# train_losses_iters 2.5723013877868652
# train_losses_iters 3.1475377082824707
# train_losses_iters 3.483074188232422
# train_losses_iters 5.3873724937438965
# train_losses_iters 3.8283886909484863
# train_losses_iters 3.3279004096984863
# train_losses_iters 2.857089042663574
# train_losses_iters 11.686347007751465
# train_losses_iters 8.168303489685059
# train_losses_iters 3.5112316608428955
# train_losses_iters 2.685696840286255
# train_losses_iters 2.5441246032714844
# train_losses_iters 2.8570961952209473
#  20%|████████▊                                   | 8/40 [04:12<15:01, 28.18s/it]
# train_losses_iters 7.110174655914307
# epoch_train_loss 5.577170017438057
# epoch_val_loss 13.930887820820013
# train_losses_iters 3.235430955886841
# train_losses_iters 3.006453514099121
# train_losses_iters 3.573061227798462
# train_losses_iters 3.941930055618286
# train_losses_iters 3.224532127380371
# train_losses_iters 3.3818485736846924
# train_losses_iters 3.5840296745300293
# train_losses_iters 3.0982398986816406
# train_losses_iters 15.543049812316895
# train_losses_iters 3.1931774616241455
# train_losses_iters 4.234035491943359
# train_losses_iters 5.0291571617126465
# train_losses_iters 2.9674158096313477
# train_losses_iters 11.380228996276855
# train_losses_iters 2.9633309841156006
# train_losses_iters 2.1205172538757324
# train_losses_iters 3.928370475769043
# train_losses_iters 3.697472333908081
# train_losses_iters 15.162208557128906
# train_losses_iters 10.473469734191895
# train_losses_iters 2.1466636657714844
# train_losses_iters 3.727750778198242
# train_losses_iters 3.4001762866973877
# train_losses_iters 3.6987221240997314
# train_losses_iters 3.101597309112549
# train_losses_iters 8.877676010131836
# train_losses_iters 13.200435638427734
# train_losses_iters 8.434793472290039
# train_losses_iters 2.618680477142334
# train_losses_iters 15.805535316467285
# train_losses_iters 17.25891876220703
# train_losses_iters 2.859774589538574
# train_losses_iters 17.30997085571289
# train_losses_iters 3.4862992763519287
# train_losses_iters 3.2195234298706055
# train_losses_iters 3.1765809059143066
# train_losses_iters 3.2826926708221436
# train_losses_iters 11.846806526184082
# train_losses_iters 16.353849411010742
# train_losses_iters 15.152474403381348
# train_losses_iters 2.9761838912963867
# train_losses_iters 3.61991810798645
# train_losses_iters 3.720126152038574
# train_losses_iters 2.726480484008789
# train_losses_iters 2.6774139404296875
# train_losses_iters 3.0977516174316406
# train_losses_iters 3.4970853328704834
# train_losses_iters 2.944077730178833
# train_losses_iters 3.396778106689453
# train_losses_iters 3.6309351921081543
# val_loss 17.446423927942913
# train_losses_iters 3.5169386863708496
# train_losses_iters 3.449896812438965
# train_losses_iters 3.329390525817871
# train_losses_iters 10.918036460876465
# train_losses_iters 3.4882071018218994
# train_losses_iters 9.209527015686035
# train_losses_iters 10.282804489135742
# train_losses_iters 2.656405210494995
# train_losses_iters 3.0156757831573486
# train_losses_iters 2.9642300605773926
# train_losses_iters 9.904685974121094
# train_losses_iters 3.430014133453369
# train_losses_iters 11.79891300201416
# train_losses_iters 2.978705406188965
# train_losses_iters 2.6991710662841797
# train_losses_iters 4.940149307250977
# train_losses_iters 12.917075157165527
# train_losses_iters 12.580041885375977
# train_losses_iters 8.878791809082031
# train_losses_iters 3.337764263153076
# train_losses_iters 3.1433141231536865
# train_losses_iters 3.224757671356201
# train_losses_iters 9.577438354492188
# train_losses_iters 3.8450276851654053
# train_losses_iters 3.1304595470428467
# train_losses_iters 3.4654064178466797
# train_losses_iters 8.82227611541748
# train_losses_iters 4.502387523651123
# train_losses_iters 3.52835750579834
# train_losses_iters 17.70720100402832
# train_losses_iters 13.575920104980469
# train_losses_iters 2.4098825454711914
# train_losses_iters 10.307744979858398
# train_losses_iters 5.40573787689209
# train_losses_iters 11.435752868652344
# train_losses_iters 2.979304075241089
# train_losses_iters 5.964347839355469
# train_losses_iters 3.3476150035858154
# train_losses_iters 2.869098424911499
# train_losses_iters 6.721432685852051
# train_losses_iters 9.710350036621094
# train_losses_iters 2.7374982833862305
# train_losses_iters 3.4695804119110107
# train_losses_iters 4.937613487243652
# train_losses_iters 3.387439012527466
# train_losses_iters 2.6518685817718506
# train_losses_iters 3.183443546295166
# train_losses_iters 4.300330638885498
# train_losses_iters 3.264719009399414
# train_losses_iters 3.6843535900115967
# val_loss 18.62793466448784
# train_losses_iters 3.184128999710083
# train_losses_iters 2.9758317470550537
# train_losses_iters 10.492975234985352
# train_losses_iters 11.54062557220459
# train_losses_iters 3.269444704055786
# train_losses_iters 5.372383117675781
# train_losses_iters 2.604691505432129
# train_losses_iters 2.3099911212921143
# train_losses_iters 3.466878652572632
# train_losses_iters 12.217142105102539
# train_losses_iters 3.1208913326263428
# train_losses_iters 3.037158489227295
# train_losses_iters 3.192385673522949
# train_losses_iters 9.391691207885742
# train_losses_iters 3.7476658821105957
# train_losses_iters 2.888115882873535
#  22%|█████████▉                                  | 9/40 [04:39<14:24, 27.89s/it]
# train_losses_iters 3.8405346870422363
# epoch_train_loss 5.805326936591385
# epoch_val_loss 14.387142429197276
# train_losses_iters 9.518489837646484
# train_losses_iters 6.4614691734313965
# train_losses_iters 11.276224136352539
# train_losses_iters 4.090083122253418
# train_losses_iters 3.6678686141967773
# train_losses_iters 8.264015197753906
# train_losses_iters 2.6657373905181885
# train_losses_iters 3.1334025859832764
# train_losses_iters 7.812343597412109
# train_losses_iters 3.7052602767944336
# train_losses_iters 2.9072346687316895
# train_losses_iters 2.854555130004883
# train_losses_iters 3.0736632347106934
# train_losses_iters 3.4134793281555176
# train_losses_iters 3.735468864440918
# train_losses_iters 11.308523178100586
# train_losses_iters 2.961355209350586
# train_losses_iters 11.198222160339355
# train_losses_iters 3.234215497970581
# train_losses_iters 3.1119744777679443
# train_losses_iters 2.8371148109436035
# train_losses_iters 10.996879577636719
# train_losses_iters 6.663771629333496
# train_losses_iters 3.7348580360412598
# train_losses_iters 2.90195369720459
# train_losses_iters 2.9238524436950684
# train_losses_iters 3.1777560710906982
# train_losses_iters 3.582365036010742
# train_losses_iters 11.195779800415039
# train_losses_iters 2.845104455947876
# train_losses_iters 3.188718557357788
# train_losses_iters 2.6965749263763428
# train_losses_iters 3.443103790283203
# train_losses_iters 3.740504264831543
# train_losses_iters 3.6614890098571777
# train_losses_iters 4.727084159851074
# train_losses_iters 2.8362810611724854
# train_losses_iters 10.814132690429688
# train_losses_iters 3.881941318511963
# train_losses_iters 3.199899673461914
# train_losses_iters 2.552389621734619
# train_losses_iters 10.912386894226074
# train_losses_iters 3.3364815711975098
# train_losses_iters 3.884246349334717
# train_losses_iters 2.8763248920440674
# train_losses_iters 2.9754478931427
# train_losses_iters 8.83822250366211
# train_losses_iters 3.214902639389038
# train_losses_iters 3.15716290473938
# train_losses_iters 13.577394485473633
# val_loss 23.530204127232235
# train_losses_iters 3.4671630859375
# train_losses_iters 2.8096680641174316
# train_losses_iters 9.790963172912598
# train_losses_iters 11.822918891906738
# train_losses_iters 8.709467887878418
# train_losses_iters 3.0653164386749268
# train_losses_iters 10.601366996765137
# train_losses_iters 2.583782911300659
# train_losses_iters 3.5197949409484863
# train_losses_iters 3.464268684387207
# train_losses_iters 3.2552030086517334
# train_losses_iters 6.953701972961426
# train_losses_iters 6.944897651672363
# train_losses_iters 2.933828830718994
# train_losses_iters 2.937572717666626
# train_losses_iters 6.848094463348389
# train_losses_iters 3.6405084133148193
# train_losses_iters 3.563300609588623
# train_losses_iters 13.696243286132812
# train_losses_iters 2.7998769283294678
# train_losses_iters 3.15755558013916
# train_losses_iters 9.023815155029297
# train_losses_iters 4.3335723876953125
# train_losses_iters 2.9593453407287598
# train_losses_iters 10.612154006958008
# train_losses_iters 2.428889513015747
# train_losses_iters 3.3065037727355957
# train_losses_iters 2.257700204849243
# train_losses_iters 11.696422576904297
# train_losses_iters 16.468517303466797
# train_losses_iters 3.063657760620117
# train_losses_iters 3.336620330810547
# train_losses_iters 2.9595139026641846
# train_losses_iters 11.400531768798828
# train_losses_iters 3.3099477291107178
# train_losses_iters 2.9446399211883545
# train_losses_iters 2.6122653484344482
# train_losses_iters 4.024012088775635
# train_losses_iters 2.9177634716033936
# train_losses_iters 3.4461400508880615
# train_losses_iters 2.781275749206543
# train_losses_iters 10.228866577148438
# train_losses_iters 3.5221171379089355
# train_losses_iters 4.676060199737549
# train_losses_iters 3.136545181274414
# train_losses_iters 11.496891975402832
# train_losses_iters 10.459927558898926
# train_losses_iters 5.382989883422852
# train_losses_iters 3.4859707355499268
# train_losses_iters 2.603264093399048
# val_loss 14.176115741332373
# train_losses_iters 2.454991579055786
# train_losses_iters 8.839475631713867
# train_losses_iters 10.814566612243652
# train_losses_iters 2.8150668144226074
# train_losses_iters 2.572442054748535
# train_losses_iters 3.0166471004486084
# train_losses_iters 2.893509864807129
# train_losses_iters 4.554474830627441
# train_losses_iters 3.2526705265045166
# train_losses_iters 2.716007709503174
# train_losses_iters 3.4304792881011963
# train_losses_iters 2.9895448684692383
# train_losses_iters 3.2020411491394043
# train_losses_iters 2.9200310707092285
# train_losses_iters 2.8386881351470947
# train_losses_iters 3.4172303676605225
#  25%|██████████▊                                | 10/40 [05:09<14:13, 28.46s/it]
# train_losses_iters 2.6425411701202393
# epoch_train_loss 5.124611414395845
# epoch_val_loss 14.833744179705779
# train_losses_iters 3.086839437484741
# train_losses_iters 2.530989646911621
# train_losses_iters 3.2347352504730225
# train_losses_iters 2.894251823425293
# train_losses_iters 3.9525907039642334
# train_losses_iters 2.8634374141693115
# train_losses_iters 4.6087541580200195
# train_losses_iters 6.989754676818848
# train_losses_iters 11.039678573608398
# train_losses_iters 2.828420877456665
# train_losses_iters 2.997631072998047
# train_losses_iters 2.9480361938476562
# train_losses_iters 8.414693832397461
# train_losses_iters 3.660475730895996
# train_losses_iters 2.3239920139312744
# train_losses_iters 13.307886123657227
# train_losses_iters 2.76639986038208
# train_losses_iters 6.757307529449463
# train_losses_iters 8.194595336914062
# train_losses_iters 2.781430244445801
# train_losses_iters 2.6804184913635254
# train_losses_iters 3.219823122024536
# train_losses_iters 6.392397403717041
# train_losses_iters 7.922456741333008
# train_losses_iters 7.639481067657471
# ...
# train_losses_iters 4.782998561859131
# train_losses_iters 2.6042582988739014
# train_losses_iters 2.274381160736084
# train_losses_iters 2.57867693901062
# train_losses_iters 4.0749382972717285
# train_losses_iters 2.755371570587158
# train_losses_iters 3.8254857063293457
# train_losses_iters 2.3864388465881348
# train_losses_iters 3.9963057041168213
# train_losses_iters 2.6527137756347656
# train_losses_iters 8.575782775878906
# train_losses_iters 2.584036111831665
# train_losses_iters 5.02754020690918
# train_losses_iters 2.5056421756744385
# train_losses_iters 2.2971439361572266
# train_losses_iters 2.5028533935546875
# train_losses_iters 6.584746360778809
# train_losses_iters 2.2671329975128174
# train_losses_iters 3.0087943077087402
# train_losses_iters 5.6560444831848145
# train_losses_iters 4.238079071044922
# train_losses_iters 5.36708927154541
# train_losses_iters 2.598440170288086
# train_losses_iters 2.2322986125946045
# train_losses_iters 2.4664463996887207
# train_losses_iters 2.7572858333587646
# train_losses_iters 2.159658670425415
# train_losses_iters 2.2781646251678467
# train_losses_iters 2.491621971130371
# train_losses_iters 2.5461790561676025
# train_losses_iters 2.3866639137268066
# train_losses_iters 2.414813995361328
# train_losses_iters 2.6082370281219482
# train_losses_iters 5.344606876373291
# train_losses_iters 2.305556058883667
# train_losses_iters 2.172420024871826
# train_losses_iters 2.9109504222869873
# train_losses_iters 2.339245557785034
# val_loss 16.304012894630432
# train_losses_iters 2.4882493019104004
# train_losses_iters 2.4229350090026855
# train_losses_iters 2.3570313453674316
# train_losses_iters 2.4448041915893555
# train_losses_iters 2.538888454437256
# train_losses_iters 2.391822338104248
# train_losses_iters 2.3243589401245117
# train_losses_iters 5.206734657287598
# train_losses_iters 5.235584735870361
# train_losses_iters 2.2660515308380127
# train_losses_iters 3.4041543006896973
# train_losses_iters 2.3410186767578125
# train_losses_iters 2.310359239578247
# train_losses_iters 2.5581722259521484
# train_losses_iters 4.4375200271606445
# train_losses_iters 2.2971885204315186
# train_losses_iters 2.4098973274230957
#  92%|███████████████████████████████████████▊   | 37/40 [18:56<01:24, 28.00s/it]
# epoch_train_loss 3.260547715374547
# epoch_val_loss 14.853297479920561
# train_losses_iters 2.2583565711975098
# train_losses_iters 3.243543863296509
# train_losses_iters 2.1477596759796143
# train_losses_iters 3.829738140106201
# train_losses_iters 4.826292991638184
# train_losses_iters 2.2516732215881348
# train_losses_iters 2.356381893157959
# train_losses_iters 2.4041504859924316
# train_losses_iters 2.658405065536499
# train_losses_iters 2.8215317726135254
# train_losses_iters 2.1661622524261475
# train_losses_iters 5.726412296295166
# train_losses_iters 2.105173349380493
# train_losses_iters 2.287358522415161
# train_losses_iters 2.557464838027954
# train_losses_iters 5.062591075897217
# train_losses_iters 2.248250722885132
# train_losses_iters 2.299365520477295
# train_losses_iters 2.490086078643799
# train_losses_iters 2.3397812843322754
# train_losses_iters 2.610499143600464
# train_losses_iters 2.02543306350708
# train_losses_iters 3.463836669921875
# train_losses_iters 4.381181716918945
# train_losses_iters 2.4246039390563965
# train_losses_iters 5.7254743576049805
# train_losses_iters 2.276567220687866
# train_losses_iters 2.3856794834136963
# train_losses_iters 2.3765463829040527
# train_losses_iters 2.376723289489746
# train_losses_iters 2.3101577758789062
# train_losses_iters 2.6895151138305664
# train_losses_iters 4.819621562957764
# train_losses_iters 2.377774238586426
# train_losses_iters 2.465383768081665
# train_losses_iters 4.625229358673096
# train_losses_iters 5.049245357513428
# train_losses_iters 2.6105098724365234
# train_losses_iters 2.402071714401245
# train_losses_iters 3.8814330101013184
# train_losses_iters 2.356292486190796
# train_losses_iters 2.492405414581299
# train_losses_iters 2.354490280151367
# train_losses_iters 2.1691877841949463
# train_losses_iters 2.676618814468384
# train_losses_iters 2.5707600116729736
# train_losses_iters 2.3058207035064697
# train_losses_iters 2.386385917663574
# train_losses_iters 2.4449141025543213
# train_losses_iters 4.534807205200195
# val_loss 20.13876438140869
# train_losses_iters 2.5175561904907227
# train_losses_iters 2.1601080894470215
# train_losses_iters 2.2300217151641846
# train_losses_iters 2.042299747467041
# train_losses_iters 5.437512397766113
# train_losses_iters 2.3208980560302734
# train_losses_iters 2.685979127883911
# train_losses_iters 2.100036382675171
# train_losses_iters 2.5809431076049805
# train_losses_iters 2.3315601348876953
# train_losses_iters 2.307332992553711
# train_losses_iters 5.179963111877441
# train_losses_iters 5.1036577224731445
# train_losses_iters 2.9233040809631348
# train_losses_iters 2.5402631759643555
# train_losses_iters 2.40408992767334
# train_losses_iters 4.85506534576416
# train_losses_iters 2.3798465728759766
# train_losses_iters 2.2968804836273193
# train_losses_iters 2.272803783416748
# train_losses_iters 2.5563111305236816
# train_losses_iters 2.178220272064209
# train_losses_iters 2.870765209197998
# train_losses_iters 2.59816837310791
# train_losses_iters 2.0204482078552246
# train_losses_iters 2.3255889415740967
# train_losses_iters 2.24172306060791
# train_losses_iters 2.642178535461426
# train_losses_iters 3.322345733642578
# train_losses_iters 2.1696665287017822
# train_losses_iters 2.1094906330108643
# train_losses_iters 2.161801815032959
# train_losses_iters 2.323103904724121
# train_losses_iters 2.1750235557556152
# train_losses_iters 3.016050100326538
# train_losses_iters 2.5261521339416504
# train_losses_iters 2.5132319927215576
# train_losses_iters 6.576925754547119
# train_losses_iters 4.832082271575928
# train_losses_iters 2.1022555828094482
# train_losses_iters 2.162135124206543
# train_losses_iters 2.0802161693573
# train_losses_iters 2.326044797897339
# train_losses_iters 2.1282503604888916
# train_losses_iters 3.909989356994629
# train_losses_iters 2.3329219818115234
# train_losses_iters 2.1174230575561523
# train_losses_iters 2.723525047302246
# train_losses_iters 2.515272378921509
# train_losses_iters 6.308195114135742
# val_loss 17.35495533545812
# train_losses_iters 2.2098469734191895
# train_losses_iters 4.474804878234863
# train_losses_iters 2.2295053005218506
# train_losses_iters 2.355802059173584
# train_losses_iters 2.2099318504333496
# train_losses_iters 2.2225494384765625
# train_losses_iters 2.4326767921447754
# train_losses_iters 4.380247116088867
# train_losses_iters 6.735404014587402
# train_losses_iters 2.206664562225342
# train_losses_iters 4.513881683349609
# train_losses_iters 6.086383819580078
# train_losses_iters 2.1558594703674316
# train_losses_iters 2.231501579284668
# train_losses_iters 2.1684727668762207
# train_losses_iters 2.281614303588867
#  95%|████████████████████████████████████████▊  | 38/40 [19:24<00:55, 27.98s/it]
# train_losses_iters 2.5502350330352783
# epoch_train_loss 2.9370141905597134
# epoch_val_loss 14.955759647776162
# train_losses_iters 2.9482674598693848
# train_losses_iters 4.0173563957214355
# train_losses_iters 6.155426979064941
# train_losses_iters 2.469275951385498
# train_losses_iters 2.3316149711608887
# train_losses_iters 1.9488478899002075
# train_losses_iters 2.4041671752929688
# train_losses_iters 2.2452688217163086
# train_losses_iters 2.518098831176758
# train_losses_iters 4.132260799407959
# train_losses_iters 2.2657222747802734
# train_losses_iters 2.208374261856079
# train_losses_iters 9.115715026855469
# train_losses_iters 2.128159761428833
# train_losses_iters 3.2734365463256836
# train_losses_iters 4.161949157714844
# train_losses_iters 3.942803382873535
# train_losses_iters 2.192927837371826
# train_losses_iters 2.598845958709717
# train_losses_iters 2.3755955696105957
# train_losses_iters 3.8021652698516846
# train_losses_iters 2.5035274028778076
# train_losses_iters 2.358328342437744
# train_losses_iters 2.044609785079956
# train_losses_iters 4.115144729614258
# train_losses_iters 2.2843496799468994
# train_losses_iters 2.347318172454834
# train_losses_iters 2.18088698387146
# train_losses_iters 4.157703399658203
# train_losses_iters 2.341559410095215
# train_losses_iters 2.087204933166504
# train_losses_iters 4.164090633392334
# train_losses_iters 2.3061351776123047
# train_losses_iters 4.820197105407715
# train_losses_iters 2.1901285648345947
# train_losses_iters 2.3139147758483887
# train_losses_iters 2.077354669570923
# train_losses_iters 2.2507832050323486
# train_losses_iters 6.128836631774902
# train_losses_iters 2.2195796966552734
# train_losses_iters 2.560194730758667
# train_losses_iters 2.6300950050354004
# train_losses_iters 2.527608871459961
# train_losses_iters 2.378357172012329
# train_losses_iters 2.099405288696289
# train_losses_iters 2.3870937824249268
# train_losses_iters 2.325695037841797
# train_losses_iters 1.9852186441421509
# train_losses_iters 2.598437786102295
# train_losses_iters 2.2330455780029297
# val_loss 16.633420904477436
# train_losses_iters 2.3688182830810547
# train_losses_iters 2.1490771770477295
# train_losses_iters 2.1515860557556152
# train_losses_iters 5.760289192199707
# train_losses_iters 2.2096471786499023
# train_losses_iters 2.307271718978882
# train_losses_iters 3.313044548034668
# train_losses_iters 2.3688998222351074
# train_losses_iters 9.806242942810059
# train_losses_iters 3.5554957389831543
# train_losses_iters 6.293176651000977
# train_losses_iters 2.3187177181243896
# train_losses_iters 2.262380838394165
# train_losses_iters 2.1137914657592773
# train_losses_iters 5.420198440551758
# train_losses_iters 2.5234084129333496
# train_losses_iters 2.202558994293213
# train_losses_iters 3.8542423248291016
# train_losses_iters 2.274419069290161
# train_losses_iters 5.601126194000244
# train_losses_iters 4.237075328826904
# train_losses_iters 2.151477336883545
# train_losses_iters 2.341775894165039
# train_losses_iters 3.632591962814331
# train_losses_iters 3.2988176345825195
# train_losses_iters 2.239427089691162
# train_losses_iters 4.047638893127441
# train_losses_iters 5.077356338500977
# train_losses_iters 2.2232725620269775
# train_losses_iters 2.1987786293029785
# train_losses_iters 2.094061851501465
# train_losses_iters 2.246894598007202
# train_losses_iters 2.3599326610565186
# train_losses_iters 2.315194606781006
# train_losses_iters 2.0680735111236572
# train_losses_iters 2.392908811569214
# train_losses_iters 2.1448957920074463
# train_losses_iters 5.001994609832764
# train_losses_iters 6.848437786102295
# train_losses_iters 6.318613529205322
# train_losses_iters 2.2659425735473633
# train_losses_iters 5.007470607757568
# train_losses_iters 2.2088685035705566
# train_losses_iters 2.386948823928833
# train_losses_iters 7.751181602478027
# train_losses_iters 4.10299825668335
# train_losses_iters 2.317713975906372
# train_losses_iters 3.881741523742676
# train_losses_iters 4.362945079803467
# train_losses_iters 4.889510631561279
# val_loss 14.501919309298197
# train_losses_iters 2.5328826904296875
# train_losses_iters 2.292865753173828
# train_losses_iters 2.4821882247924805
# train_losses_iters 4.2484893798828125
# train_losses_iters 2.2009644508361816
# train_losses_iters 2.184558153152466
# train_losses_iters 2.339280605316162
# train_losses_iters 2.2303969860076904
# train_losses_iters 2.534163236618042
# train_losses_iters 2.449878215789795
# train_losses_iters 2.2879154682159424
# train_losses_iters 2.2663815021514893
# train_losses_iters 2.1205813884735107
# train_losses_iters 5.810362815856934
# train_losses_iters 2.7612903118133545
# train_losses_iters 2.2331268787384033
# train_losses_iters 2.7736074924468994
#  98%|█████████████████████████████████████████▉ | 39/40 [19:53<00:28, 28.15s/it]
# epoch_train_loss 3.1527431867061515
# epoch_val_loss 14.971449659548256
# train_losses_iters 2.2827587127685547
# train_losses_iters 2.6508185863494873
# train_losses_iters 2.4359335899353027
# train_losses_iters 2.13018798828125
# train_losses_iters 2.2107620239257812
# train_losses_iters 2.2299208641052246
# train_losses_iters 4.161649703979492
# train_losses_iters 2.02751088142395
# train_losses_iters 2.198331832885742
# train_losses_iters 2.886848211288452
# train_losses_iters 4.163015365600586
# train_losses_iters 5.631760597229004
# train_losses_iters 2.3748879432678223
# train_losses_iters 2.444596290588379
# train_losses_iters 2.3881640434265137
# train_losses_iters 2.491826057434082
# train_losses_iters 2.633986473083496
# train_losses_iters 2.412400960922241
# train_losses_iters 2.2940735816955566
# train_losses_iters 2.105245590209961
# train_losses_iters 3.462643623352051
# train_losses_iters 2.0677101612091064
# train_losses_iters 7.6075029373168945
# train_losses_iters 2.0583858489990234
# train_losses_iters 2.248976945877075
# train_losses_iters 2.5155181884765625
# train_losses_iters 6.49543571472168
# train_losses_iters 4.963508605957031
# train_losses_iters 2.4252266883850098
# train_losses_iters 4.196659564971924
# train_losses_iters 2.124432325363159
# train_losses_iters 6.400649070739746
# train_losses_iters 2.169955253601074
# train_losses_iters 4.212732791900635
# train_losses_iters 2.6369197368621826
# train_losses_iters 4.246997356414795
# train_losses_iters 5.407085418701172
# train_losses_iters 2.160179376602173
# train_losses_iters 2.337981700897217
# train_losses_iters 2.0806636810302734
# train_losses_iters 3.8581528663635254
# train_losses_iters 2.183858871459961
# train_losses_iters 2.4359681606292725
# train_losses_iters 2.159895658493042
# train_losses_iters 2.2052578926086426
# train_losses_iters 2.379713296890259
# train_losses_iters 2.2448322772979736
# train_losses_iters 2.216538906097412
# train_losses_iters 2.9887759685516357
# train_losses_iters 2.118469715118408
# val_loss 15.755790024995804
# train_losses_iters 2.1476805210113525
# train_losses_iters 5.5233073234558105
# train_losses_iters 2.262962818145752
# train_losses_iters 4.805841445922852
# train_losses_iters 2.478511333465576
# train_losses_iters 2.316307306289673
# train_losses_iters 2.245255470275879
# train_losses_iters 2.3368661403656006
# train_losses_iters 2.5575952529907227
# train_losses_iters 2.0782575607299805
# train_losses_iters 4.326480865478516
# train_losses_iters 2.661175489425659
# train_losses_iters 2.4466521739959717
# train_losses_iters 2.1167099475860596
# train_losses_iters 2.7200372219085693
# train_losses_iters 2.167555570602417
# train_losses_iters 2.3745789527893066
# train_losses_iters 2.397994041442871
# train_losses_iters 2.2188761234283447
# train_losses_iters 2.4522812366485596
# train_losses_iters 2.1839921474456787
# train_losses_iters 1.9876097440719604
# train_losses_iters 8.057897567749023
# train_losses_iters 3.3931381702423096
# train_losses_iters 3.0708820819854736
# train_losses_iters 4.7188944816589355
# train_losses_iters 2.3492140769958496
# train_losses_iters 3.162015914916992
# train_losses_iters 2.306462287902832
# train_losses_iters 2.3140509128570557
# train_losses_iters 2.117058038711548
# train_losses_iters 2.66544246673584
# train_losses_iters 2.1055140495300293
# train_losses_iters 2.2795941829681396
# train_losses_iters 2.429947853088379
# train_losses_iters 2.2006866931915283
# train_losses_iters 4.35087776184082
# train_losses_iters 2.5310897827148438
# train_losses_iters 2.565506935119629
# train_losses_iters 3.1851911544799805
# train_losses_iters 2.495877504348755
# train_losses_iters 2.33315372467041
# train_losses_iters 2.2040998935699463
# train_losses_iters 2.2089977264404297
# train_losses_iters 2.1559371948242188
# train_losses_iters 2.316110134124756
# train_losses_iters 2.3213815689086914
# train_losses_iters 2.5105061531066895
# train_losses_iters 2.8088417053222656
# train_losses_iters 2.354421377182007
# val_loss 6.314928154150645
# train_losses_iters 2.2711246013641357
# train_losses_iters 4.591678142547607
# train_losses_iters 2.1522574424743652
# train_losses_iters 6.53411340713501
# train_losses_iters 2.195918321609497
# train_losses_iters 3.726510763168335
# train_losses_iters 6.705260753631592
# train_losses_iters 2.1044816970825195
# train_losses_iters 4.281356334686279
# train_losses_iters 2.2412235736846924
# train_losses_iters 2.466717004776001
# train_losses_iters 5.164613723754883
# train_losses_iters 4.438057899475098
# train_losses_iters 2.2250866889953613
# train_losses_iters 2.179511785507202
# train_losses_iters 2.2479171752929688
# 100%|███████████████████████████████████████████| 40/40 [20:20<00:00, 30.52s/it]
# train_losses_iters 5.358888149261475
# epoch_train_loss 2.9911909867555666
# epoch_val_loss 14.87304739529888

# %%
torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, './barlowtscp'+DS_NAME+str(WIN)+str(CODE_SIZE)+str(BATCH_SIZE)+'_opt.pt')

# %%
cpt = torch.load('barlowtscpUSC1001032_opt.pt')
model.load_state_dict(cpt['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
enc = model.get_enc()

# %%
test_ds = load_future(DATA_PATH, DS_NAME, WIN, BATCH_SIZE, mode = "test")
# Out:
# number of samples : 2336 /  number of samples with change point : 175
# test shape (468, 200) and number of change points 35
# (468, 200) (468, 1)
# dataset shape :  (468, 201)

# %%
x_test, lbl_test = test_ds[:,1:], test_ds[:,0]

num = x_test.shape[0]
lbl_test = np.array(lbl_test).reshape((lbl_test.shape[0], 1))
history = enc(torch.from_numpy(x_test[:, 0:WIN].reshape((num, 1, WIN))).float())
future = enc(torch.from_numpy(x_test[:, WIN:].reshape((num, 1, WIN))).float())
pred_out = np.concatenate((lbl_test, history.detach().numpy(), future.detach().numpy()), 1)
rep_sim = _cosine_simililarity_dim1(history, future)

print('Average similarity for test set : Reps : {}'.format(np.mean(rep_sim.detach().numpy())))
gt = np.zeros(lbl_test.shape[0])
gt[np.where((lbl_test > int(2 * WIN * 0.15)) & (lbl_test < int(2 * WIN * 0.85)))[0]] = 1
result = estimate_CPs(rep_sim.detach().numpy(), gt, os.path.join(OUTPUT_PATH, train_name),
                    os.path.join(OUTPUT_PATH, "Evaluation.txt"),
                    metric='cosine', threshold=0.5)
# Out:
# /home/bogdan/.local/lib/python3.10/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
# Average similarity for test set : Reps : 0.999922513961792
# tn 442, fp 0, fn 26, tp 0 ----- f1-score 0.0
# SEQ : Pos 7, fp 0, fn 7, tp 0 ----- f1-score 0.0

# %%
result = estimate_CPs(rep_sim.detach().numpy(), gt, os.path.join(OUTPUT_PATH, train_name),
                    os.path.join(OUTPUT_PATH, "Evaluation.txt"),
                    metric='cosine', threshold=0.9)
# Out:
# tn 442, fp 0, fn 26, tp 0 ----- f1-score 0.0
# SEQ : Pos 7, fp 0, fn 7, tp 0 ----- f1-score 0.0
